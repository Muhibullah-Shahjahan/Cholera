# %% [markdown]
# ### import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## read file

# %%
dataSet = pd.read_csv('data_file/Cholera.csv')

# %%
dataSet.head()
# Out:
#        Country  Year Number of reported cases of cholera  \
# 0  Afghanistan  2016                                 677
# 1  Afghanistan  2015                               58064
# 2  Afghanistan  2014                               45481
# 3  Afghanistan  2013                                3957
# 4  Afghanistan  2012                                  12
#
#   Number of reported deaths from cholera Cholera case fatality rate  \
# 0                                      5                        0.7
# 1                                      8                       0.01
# 2                                      4                          0
# 3                                     14                       0.35
# 4                                      0                        0.1
#
#               WHO Region
# 0  Eastern Mediterranean
# 1  Eastern Mediterranean
# 2  Eastern Mediterranean
# 3  Eastern Mediterranean
# 4  Eastern Mediterranean

# %%
dataSet.tail()
# Out:
#                  Country  Year Number of reported cases of cholera  \
# 2487  Russian Federation  1980                                 NaN
# 2488  Russian Federation  1971                                 NaN
# 2489              Sweden  1984                                 NaN
# 2490         Switzerland  1980                                 NaN
# 2491            Cambodia  2011                                 NaN
#
#      Number of reported deaths from cholera Cholera case fatality rate  \
# 2487                                      0                        NaN
# 2488                                      0                        NaN
# 2489                                      0                        NaN
# 2490                                      0                        NaN
# 2491                                    NaN                          0
#
#            WHO Region
# 2487           Europe
# 2488           Europe
# 2489           Europe
# 2490           Europe
# ...

# %%
dataSet.columns
# Out:
# Index(['Country', 'Year', 'Number of reported cases of cholera',
#        'Number of reported deaths from cholera', 'Cholera case fatality rate',
#        'WHO Region'],
#       dtype='object')

# %%
dataSet.shape
# Out:
# (2492, 6)

# %%
dataSet.dtypes
# Out:
# Country                                   object
# Year                                       int64
# Number of reported cases of cholera       object
# Number of reported deaths from cholera    object
# Cholera case fatality rate                object
# WHO Region                                object
# dtype: object

# %%
YearlyReportedCase=dataSet.filter(items=["Year","Number of reported deaths from cholera"])

# %%
dataSet.describe().T
# Out:
#        count         mean        std     min     25%     50%     75%     max
# Year  2492.0  1992.343098  14.834151  1949.0  1981.0  1994.0  2004.0  2016.0

# %%
YearlyReportedCase
# Out:
#       Year Number of reported deaths from cholera
# 0     2016                                      5
# 1     2015                                      8
# 2     2014                                      4
# 3     2013                                     14
# 4     2012                                      0
# ...    ...                                    ...
# 2487  1980                                      0
# 2488  1971                                      0
# 2489  1984                                      0
# 2490  1980                                      0
# 2491  2011                                    NaN
#
# [2492 rows x 2 columns]

# %%
dataSet[["Year","Number of reported cases of cholera"]].describe()
# Out:
#               Year
# count  2492.000000
# mean   1992.343098
# std      14.834151
# min    1949.000000
# 25%    1981.000000
# 50%    1994.000000
# 75%    2004.000000
# max    2016.000000

# %%
len(dataSet['Country'].unique())
# Out:
# 162

# %%
pd.crosstab(dataSet['WHO Region'],dataSet['Number of reported deaths from cholera'])
# Out:
# Number of reported deaths from cholera    0  0 0   1  10  100  101  1011  \
# WHO Region
# Africa                                  162    0  36  10    2    1     0
# Americas                                108    0  13   2    0    0     0
# Eastern Mediterranean                    66    1  14   3    0    0     1
# Europe                                  258    0   8   2    0    0     0
# South-East Asia                          47    0   9   2    0    0     0
# Western Pacific                         175    0  40   4    0    0     0
#
# Number of reported deaths from cholera  10119  102  103  ...  941  9443  95  \
# WHO Region                                               ...
# Africa                                      0    4    1  ...    1     0   2
# Americas                                    0    2    0  ...    0     0   1
# Eastern Mediterranean                       0    0    1  ...    0     0   0
# Europe                                      0    0    0  ...    0     0   0
# ...

# %%
dataSet.isnull().count()
# Out:
# Country                                   2492
# Year                                      2492
# Number of reported cases of cholera       2492
# Number of reported deaths from cholera    2492
# Cholera case fatality rate                2492
# WHO Region                                2492
# dtype: int64

# %% [markdown]
# # data cleaning

# %%
dataSet.isnull().sum()
# Out:
# Country                                     0
# Year                                        0
# Number of reported cases of cholera        22
# Number of reported deaths from cholera    117
# Cholera case fatality rate                127
# WHO Region                                  0
# dtype: int64

# %%
dataSet['Number of reported cases of cholera'] = dataSet['Number of reported cases of cholera'].fillna(method='ffill')

# %%
dataSet['Cholera case fatality rate'] = dataSet['Cholera case fatality rate'].fillna(method='ffill')

# %%
dataSet.isnull().sum()
# Out:
# Country                                     0
# Year                                        0
# Number of reported cases of cholera         0
# Number of reported deaths from cholera    117
# Cholera case fatality rate                  0
# WHO Region                                  0
# dtype: int64

# %%
dataSet['Number of reported deaths from cholera'] = dataSet['Number of reported deaths from cholera'].fillna(method='ffill')

# %%
dataSet.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# Number of reported cases of cholera       0
# Number of reported deaths from cholera    0
# Cholera case fatality rate                0
# WHO Region                                0
# dtype: int64

# %%
dataSet.dtypes
# Out:
# Country                                   object
# Year                                       int64
# Number of reported cases of cholera       object
# Number of reported deaths from cholera    object
# Cholera case fatality rate                object
# WHO Region                                object
# dtype: object

# %% [markdown]
# # data selecting

# %%
bd = dataSet[dataSet['Country'] == 'Bangladesh']

# %%
bd
# Out:
#         Country  Year Number of reported cases of cholera  \
# 128  Bangladesh  2000                                1021
# 129  Bangladesh  1999                                3440
# 130  Bangladesh  1998                                1067
# 131  Bangladesh  1997                                1959
# 132  Bangladesh  1996                                 418
# 133  Bangladesh  1995                                2297
# 134  Bangladesh  1994                                 562
# 135  Bangladesh  1993                                  78
# 136  Bangladesh  1992                                 479
# 137  Bangladesh  1991                                   8
# 138  Bangladesh  1990                                  82
# 139  Bangladesh  1989                                  94
# 140  Bangladesh  1988                                 571
# 141  Bangladesh  1987                                 523
# 142  Bangladesh  1979                                2154
# ...

# %%
bd.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# Number of reported cases of cholera       0
# Number of reported deaths from cholera    0
# Cholera case fatality rate                0
# WHO Region                                0
# dtype: int64

# %%
plt.subplots(figsize = (8,10))
plt.plot(bd["Year"],bd['Number of reported cases of cholera'],linewidth=5)
plt.xlabel('years')
plt.ylabel('Number of reported cases of cholera')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-179-386e8a6aeda9> in <module>
#       1 plt.subplots(figsize = (8,10))
#       2 plt.plot(bd["Year"],bd['Number of reported cases of cholera'],linewidth=5)
# ----> 3 plt.set_xlabel('years')
#       4 plt.set_ylabel('Number of reported cases of cholera')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xlabel'

# %%
fig,ax=plt.subplots(figsize=(12,14))
ax.plot(bd['Year'],bd['Number of reported cases of cholera'],color='red')
ax.set_xlabel('year',fontsize=14)
ax.set_ylabel('number of reported cases of cholera', color="red",fontsize=14)

ax2 = plt.twinx()
ax2.plot(bd['Year'],bd['Number of reported deaths from cholera'],color='blue')
ax2.set_ylabel('Number of reported deaths from cholera',color='blue',fontsize=14)
plt.show()
